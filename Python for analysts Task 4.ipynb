# %% [markdown]
# ## Условие 1: Задача 1
# ### Постройте график
# ### Назовите график
# ### Сделайте именование оси x и оси y
# ### Сделайте выводы
#
# ### 1.1. Скачать данные по ссылке

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('./kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ### 1.2 Изучите стоимости недвижимости

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.sample (n = 10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 16537  8887001192  20140620T000000  355000.0         2       1.00
# 16481  4060000290  20140617T000000  253000.0         3       1.50
# 9975   8731801260  20150220T000000  234000.0         3       1.75
# 7939   8856920110  20150504T000000  360000.0         3       2.50
# 12310  7529500030  20140909T000000  385000.0         6       4.00
# 8526   3330501120  20150325T000000  320000.0         3       1.00
# 7292   5561400440  20140827T000000  465000.0         4       2.50
# 18531  5151600300  20140812T000000  390000.0         4       2.75
# 1800   3356404330  20141119T000000  206000.0         4       2.00
# 16202  1950900005  20141003T000000  185000.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16537         1240     27042     1.0           0     1  ...      6
# 16481          880      6600     1.0           0     0  ...      6
# ...

# %% [markdown]
#  _**Стандартный синтаксис создания графика**_

# %%
plt.figure(figsize = (8,6))
plt.hist(df['price'])
plt.title ('Стоимость недвижимости')
plt.xlabel('Цена')
plt.ylabel('Количество')
plt.grid();

# %%
df_num_features = df.select_dtypes(include=['float64', 'float32', 'float16'])
df_num_features.drop('price', axis=1, inplace=True)

# %%
df_num_features.hist(figsize=(16, 16), bins=20, grid=False);

# %% [markdown]
# ### 1.3 Изучите распределение квадратуры жилой

# %%
plt.figure(figsize = (8,6))
plt.hist(df['sqft_living'])
plt.title ('Распределение квадратуры жилой')
plt.xlabel('Квадратура жилой')
plt.ylabel('Количество')
plt.grid();

# %% [markdown]
# ### 1.4 Изучите распределение года постройки

# %%
plt.figure(figsize = (8,6))
plt.hist(df['yr_built'])
plt.title ('Год постройки')
plt.xlabel('Дата, год')
plt.ylabel('Количество')
plt.grid();

# %% [markdown]
# ## Условие 2: 2 задача

# %% [markdown]
# ### 2.1 Изучите распределение домов от наличия вида на набережную
# ### Постройте график
# ### Сделайте выводы

# %%
plt.figure(figsize = (8,6))
plt.hist(df['waterfront'])
plt.title ('Наличие вида на набережную')
plt.xlabel('Вид на набережную')
plt.ylabel('Количество')
plt.grid();

# %% [markdown]
# ### 2.2 Изучите распределение этажей домов

# %%
plt.figure(figsize = (8,6))
plt.hist(df['floors'])
plt.title ('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество домов')
plt.grid();

# %% [markdown]
# ### 2.2 Изучите распределение состояния домов

# %%
plt.figure(figsize = (8,6))
plt.hist(df['view'])
plt.title ('Распределение состояния домов')
plt.xlabel('Вид состояния')
plt.ylabel('Количество домов')
plt.grid();

# %% [markdown]
# ## Условие 3: 3 задача

# %% [markdown]
# ### Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# ### Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
sns.jointplot(x=df['price'], y=df['waterfront'], kind ='reg');

# %%
sns.jointplot(x=df['price'], y=df['waterfront'], kind='kde');

# %% [markdown]
# ### Видим прямую зависимость цены недвижимости от вида из окна на водоем.

# %%
sns.jointplot(x=df['lat'], y=df['long'], kind='kde');

# %%
sns.jointplot(x=df['bedrooms'], y=df['bathrooms'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['bathrooms'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['bathrooms'], kind='kde');

# %%
sns.jointplot(x=df['price'], y=df['bedrooms'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['bedrooms'], kind='kde');

# %%
sns.jointplot(x=df['lat'], y=df['long'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['long'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['lat'], kind='reg');

# %% [markdown]
# ### Стоимость недвижимости изменяется от географической широты больше, чем от долготы

# %%
sns.jointplot(x=df['price'], y=df['view'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['view'], kind='kde');

# %%
sns.jointplot(x=df['price'], y=df['yr_built'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['yr_built'], kind='kde');

# %% [markdown]
# ### Цена зависит от вида недвижимости, особенно если срок эксплуатации маленький

# %%
sns.jointplot(x=df['price'], y=df['grade'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['floors'], kind='reg');

# %%
sns.jointplot(x=df['price'], y=df['floors'], kind='kde');

# %% [markdown]
# ### Недвижимость с одним или двумя этажами имеет больше предложений по цене.

# %% [markdown]
# ### Вывод: Видим прямую зависимость цены недвижимости от вида из окна на водоем,
# ### Стоимость недвижимости изменяется от географической широты больше, чем от долготы,
# ### Цена зависит от вида недвижимости, особенно если срок эксплуатации маленький,
# ### Недвижимость с одним или двумя этажами имеет больше предложений по цене,
# ### Цена недвижимости больше зависит от количества ванных комнат, чем от количества спален.
